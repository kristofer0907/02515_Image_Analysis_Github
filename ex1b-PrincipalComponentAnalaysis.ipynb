# %%
# Exercise 1 Start by reading the data and create a data matrix x: 
# %%
import numpy as np
import sys

in_dir = "/home/kkristjansson/DTU/spring2026/02515_Image_Analysis/imageAnalysisGithub/exercises/ex1b-PCA/data/"
txt_name = "irisdata.txt"
iris_data = np.loadtxt(in_dir+txt_name, comments = "%")


x =  iris_data[0:50,0:4]

n_feat = x.shape[1]
n_obs = x.shape[0]

print(f"Number of features: {n_feat} and number of observations: {n_obs}")
# Out:
# Number of features: 4 and number of observations: 50

# %%
# Exercise 2: To explore the data, we can create vectors of the individual feature:
# %%
sep_l = x[:, 0]
sep_w = x[:, 1]
pet_l = x[:, 2]
pet_w = x[:, 3]

# Use ddof = 1 to make an unbiased estimate
var_sep_l = sep_l.var(ddof=1)
var_sep_w = sep_w.var(ddof=1)
var_pet_l = pet_l.var(ddof=1)
var_pet_w = pet_w.var(ddof=1)
